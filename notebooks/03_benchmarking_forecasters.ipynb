# %% [markdown]
# # Benchmarking Global Forecasting Models
#
# ### Recap Advantages / Disadvantages Time Series Foundation Models
#
# ![](./img/advantages_disadvantages.png)

# %% [markdown]
# ![](./img/motivation_benchmarking.png)

# %% [markdown]
# ## Requirements
#
# ![](./img/requirements_benchmarking.png)

# %% [markdown]
# ## Benchmarking Module in sktime
#
# <style>
# table th:first-of-type {
#     width: 20%;
# }
# table th:nth-of-type(2) {
#     width: 40%;
# }
# table th:nth-of-type(3) {
#     width: 20%;
# }
# </style>
#
# | Add estimator  <br /> E.g. ChronosForecaster() | ![](./img/sktime_benchmarking.png) |  Add task  <br /> dataset loader   <br /> Cross Validation  <br /> Global Cross Validation  <br /> Global Temporal Cross Validation  <br /> Scoring Metrics|
# :-----------------:|:-------------------------:|:-------------------------:

# %%
from sktime.benchmarking.forecasting import ForecastingBenchmark
from sktime.performance_metrics.forecasting import MeanAbsoluteError, MeanSquaredError
from sktime.split import SingleWindowSplitter, InstanceSplitter
from sktime.datasets import load_forecastingdata 
from sklearn.model_selection import KFold

# %% [markdown]
# ## Data loader

# %%
def dataset_loader():
    data = load_forecastingdata("australian_electricity_demand_dataset", return_type="pd_multiindex_hier")[0]
    data = data[data.index.get_level_values(-1) <  "2009.01.01"]
    data.index = data.index.droplevel(0)
    return data

# %% [markdown]
# ## Cross Validation
# * cv is a SingleWindowSplitter, this cv splits the time series into two pieces
#     * the context, which is passed to the forecaster
#     * the ground truth, which should be forecasted (determined by `fh=range(1, 48)`)
# * cv_global is an InstanceSplitter, it splits the time series into two sets:
#     * known time series that might be used for training global forecasting models. The used time series foundation models will ignore these time series in this benchmark.
#     * unknown time series, which will be splitted into context and values to be predicted.
# * cv_temporal_global which is a SingleWindowSplitter, it determines the cutoff point which is synced across the known and unknown time series to avoid temporal data leakage between both sets.
#
# ![](./img/split_explanation.png)

# %% [markdown]
# ### Visualise the splits (TODO Remove it not merged!)

# %%
# We need to release this method!
from sktime.utils.plotting import plot_folds_global_forecasting


data = dataset_loader()
data = data[data.index.get_level_values(-1) < data.index.get_level_values(-1)[1000]]

cv = SingleWindowSplitter(fh=range(1, 168))
cv_global = InstanceSplitter(KFold(5))#
cv_temporal_global = SingleWindowSplitter(fh=range(1, 168*2))

plot_folds_global_forecasting(
    cv,
    cv_global,
    cv_temporal_global,
    data,
)
# Out:
# (<Figure size 1600x1500 with 10 Axes>,
#  array([[<Axes: xlabel='timestamp'>,
#          <Axes: title={'center': 'NSW'}, xlabel='timestamp'>],
#         [<Axes: xlabel='timestamp'>,
#          <Axes: title={'center': 'VIC'}, xlabel='timestamp'>],
#         [<Axes: xlabel='timestamp'>,
#          <Axes: title={'center': 'QUN'}, xlabel='timestamp'>],
#         [<Axes: xlabel='timestamp'>,
#          <Axes: title={'center': 'SA'}, xlabel='timestamp'>],
#         [<Axes: xlabel='timestamp'>,
#          <Axes: title={'center': 'TAS'}, xlabel='timestamp'>]],
#        dtype=object))

# %% [markdown]
# ## Metrics
#
# * Metrics are first class citizen in sktime. I.e., they are classes with a tag system and are searchable.
# * located in `sktime.performance_metrics.forecasting`
# * Probabilistic/Point Forecasting metric.
# * Based on the chosen metric, the benchmarking module decides if a probabilistic or a point forecast should be evaluated.

# %%
from sktime.performance_metrics.forecasting import MeanAbsoluteError

from sktime.registry import all_estimators

all_estimators("metric", as_dataframe=True)
# Out:
#                                   name  \
# 0                        AUCalibration
# 1                                 CRPS
# 2                  ConstraintViolation
# 3                       DetectionCount
# 4                      DirectedChamfer
# 5                    DirectedHausdorff
# 6                    EmpiricalCoverage
# 7           GeometricMeanAbsoluteError
# 8   GeometricMeanRelativeAbsoluteError
# 9    GeometricMeanRelativeSquaredError
# 10           GeometricMeanSquaredError
# 11                       IntervalWidth
# 12                             LogLoss
# 13                   MeanAbsoluteError
# 14         MeanAbsolutePercentageError
# 15             MeanAbsoluteScaledError
# 16                 MeanAsymmetricError
# 17                      MeanLinexError
# 18           MeanRelativeAbsoluteError
# 19                    MeanSquaredError
# 20          MeanSquaredErrorPercentage
# 21          MeanSquaredPercentageError
# 22              MeanSquaredScaledError
# 23                 MedianAbsoluteError
# 24       MedianAbsolutePercentageError
# 25           MedianAbsoluteScaledError
# 26         MedianRelativeAbsoluteError
# 27                  MedianSquaredError
# 28        MedianSquaredPercentageError
# 29            MedianSquaredScaledError
# 30                         PinballLoss
# 31                           RandIndex
# 32                        RelativeLoss
# 33                    SquaredDistrLoss
# 34                     TimeSeriesAUPRC
# 35                     WindowedF1Score
#
#                                                object
# 0   <class 'sktime.performance_metrics.forecasting...
# 1   <class 'sktime.performance_metrics.forecasting...
# 2   <class 'sktime.performance_metrics.forecasting...
# 3   <class 'sktime.performance_metrics.detection._...
# 4   <class 'sktime.performance_metrics.detection._...
# 5   <class 'sktime.performance_metrics.detection._...
# 6   <class 'sktime.performance_metrics.forecasting...
# 7   <class 'sktime.performance_metrics.forecasting...
# 8   <class 'sktime.performance_metrics.forecasting...
# 9   <class 'sktime.performance_metrics.forecasting...
# 10  <class 'sktime.performance_metrics.forecasting...
# 11  <class 'sktime.performance_metrics.forecasting...
# 12  <class 'sktime.performance_metrics.forecasting...
# 13  <class 'sktime.performance_metrics.forecasting...
# 14  <class 'sktime.performance_metrics.forecasting...
# 15  <class 'sktime.performance_metrics.forecasting...
# 16  <class 'sktime.performance_metrics.forecasting...
# 17  <class 'sktime.performance_metrics.forecasting...
# 18  <class 'sktime.performance_metrics.forecasting...
# 19  <class 'sktime.performance_metrics.forecasting...
# 20  <class 'sktime.performance_metrics.forecasting...
# 21  <class 'sktime.performance_metrics.forecasting...
# 22  <class 'sktime.performance_metrics.forecasting...
# 23  <class 'sktime.performance_metrics.forecasting...
# 24  <class 'sktime.performance_metrics.forecasting...
# 25  <class 'sktime.performance_metrics.forecasting...
# 26  <class 'sktime.performance_metrics.forecasting...
# 27  <class 'sktime.performance_metrics.forecasting...
# 28  <class 'sktime.performance_metrics.forecasting...
# 29  <class 'sktime.performance_metrics.forecasting...
# 30  <class 'sktime.performance_metrics.forecasting...
# 31  <class 'sktime.performance_metrics.detection._...
# 32  <class 'sktime.performance_metrics.forecasting...
# 33  <class 'sktime.performance_metrics.forecasting...
# 34  <class 'sktime.performance_metrics.detection._...
# 35  <class 'sktime.performance_metrics.detection._...

# %% [markdown]
# ## Create a Forecasting Benchmark with global forecasters

# %%
benchmark = ForecastingBenchmark()

# %% [markdown]
# ## Add tasks
# * 5 splits (each time series will be a test time series once)
# * Two metrics
#     * Root mean squared error (`MeanSquaredError(square_root=True)`)
#     * Mean absolute error with forecast horizon based evaluation (`MeanAbsoluteError(by_index=True)`)
# * In case of a failing forecast, the benchmark should raise an exception (`error_score="raise"`).

# %%
benchmark.add_task(
        dataset_loader,
        SingleWindowSplitter(fh=range(1, 48)),
        [MeanSquaredError(square_root=True), MeanAbsoluteError(by_index=True)],
        cv_global=InstanceSplitter(KFold(5)),
        cv_global_temporal=SingleWindowSplitter(fh=range(1, 48*24)),
        error_score="raise"
    )

# %% [markdown]
# ## Add estimators

# %%
from sktime.forecasting.chronos import ChronosForecaster
from sktime.forecasting.ttm import TinyTimeMixerForecaster
from sktime.forecasting.moirai_forecaster import MOIRAIForecaster

# %%
benchmark.add_estimator(
    ChronosForecaster("amazon/chronos-bolt-tiny"), estimator_id="chronos_bolt"
)
# benchmark.add_estimator(
#     ChronosForecaster("amazon/chronos-bolt-base"), estimator_id="chronos_base"
# )
# benchmark.add_estimator(
#     TinyTimeMixerForecaster()
# )
# benchmark.add_estimator(
#     MOIRAIForecaster(checkpoint_path=f"sktime/moirai-1.0-R-small"), estimator_id="moirai_small"
# )
# benchmark.add_estimator(
#     MOIRAIForecaster(checkpoint_path=f"sktime/moirai-1.0-R-large"), estimator_id="moirai_large"
# )

# %%
results = benchmark.run("energy_benchmarking.json", force_rerun = True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 results = benchmark.run("energy_benchmarking.json", force_rerun =True)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\benchmarking\benchmarks.py:348, in BaseBenchmark.run(self, output_file, force_rerun)
#     335 def run(self, output_file: str, force_rerun: str | list[str] = "none"):
#     336     """
#     337     Run the benchmarking for all tasks and estimators.
#     338
#    (...)    346         If list of str, will run validation for tasks and models in list.
#     347     """
# --> 348     return self._run(output_file, force_rerun)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\benchmarking\benchmarks.py:323, in BaseBenchmark._run(self, results_path, force_rerun)
#     320             continue
#     322         logging.info(f"Running validation - model: {task_id} - {estimator_id}")
# --> 323         folds = self._run_validation(task, estimator)
#     324         results.results.append(
#     325             ResultObject(
#     326                 task_id=task_id,
#    (...)    329             )
#     330         )
#     332 results.save()
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\benchmarking\forecasting.py:182, in ForecastingBenchmark._run_validation(self, task, estimator)
#     180 scorers = task.scorers
#     181 y, X = task.get_y_X()
# --> 182 scores_df = evaluate(
#     183     forecaster=estimator,
#     184     y=y,
#     185     X=X,
#     186     cv=cv_splitter,
#     187     scoring=scorers,
#     188     backend=self.backend,
#     189     backend_params=self.backend_params,
#     190     error_score=task.error_score,
#     191     return_data=self.return_data,
#     192     cv_X=task.cv_X,
#     193     cv_global=task.cv_global,
#     194     strategy=task.strategy,
#     195     return_model=False,
#     196     cv_global_temporal=task.cv_global_temporal,
#     197 )
#     199 folds = {}
#     200 for ix, row in scores_df.iterrows():
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\model_evaluation\_functions.py:809, in evaluate(forecaster, cv, y, X, strategy, scoring, return_data, error_score, backend, cv_X, backend_params, return_model, cv_global, cv_global_temporal)
#     807     else:
#     808         backend_in = backend
# --> 809     results = parallelize(
#     810         fun=_evaluate_window,
#     811         iter=enumerate(yx_splits),
#     812         meta=_evaluate_window_kwargs,
#     813         backend=backend_in,
#     814         backend_params=backend_params,
#     815     )
#     817 # final formatting of dask dataframes
#     818 if backend in ["dask", "dask_lazy"] and not not_parallel:
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\utils\parallel.py:86, in parallelize(fun, iter, meta, backend, backend_params)
#      83 backend_name = backend_dict[backend]
#      84 para_fun = para_dict[backend_name]
# ---> 86 ret = para_fun(
#      87     fun=fun, iter=iter, meta=meta, backend=backend, backend_params=backend_params
#      88 )
#      89 return ret
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\utils\parallel.py:107, in _parallelize_none(fun, iter, meta, backend, backend_params)
#     105 def _parallelize_none(fun, iter, meta, backend, backend_params):
#     106     """Execute loop via simple sequential list comprehension."""
# --> 107     ret = [fun(x, meta=meta) for x in iter]
#     108     return ret
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\model_evaluation\_functions.py:289, in _evaluate_window(x, meta)
#     287 except Exception as e:
#     288     if error_score == "raise":
# --> 289         raise e
#     290     else:  # assign default value when fitting failed
#     291         for scitype in scoring:
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\model_evaluation\_functions.py:268, in _evaluate_window(x, meta)
#     266 start_pred = time.perf_counter()
#     267 if global_mode:
# --> 268     y_pred = method(fh=fh, X=X_test, y=y_hist, **pred_args)
#     269 else:
#     270     y_pred = method(fh=fh, X=X_test, **pred_args)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\chronos.py:518, in ChronosForecaster.predict(self, fh, X, y)
#     515     _fh = self._fh
#     517 if y is not None:
# --> 518     return self.fit_predict(fh=_fh, X=X, y=y)
#     520 return super().predict(fh=fh, X=X)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\base\_base.py:575, in BaseForecaster.fit_predict(self, y, X, fh, X_pred)
#     572 self._is_fitted = True
#     573 # call the public predict to avoid duplicating output conversions
#     574 #  input conversions are skipped since we are using X_inner
# --> 575 return self.predict(fh=fh, X=X_inner)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\chronos.py:520, in ChronosForecaster.predict(self, fh, X, y)
#     517 if y is not None:
#     518     return self.fit_predict(fh=_fh, X=X, y=y)
# --> 520 return super().predict(fh=fh, X=X)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\base\_base.py:461, in BaseForecaster.predict(self, fh, X)
#     458     y_pred = self._predict(fh=fh, X=X_inner)
#     459 else:
#     460     # otherwise we call the vectorized version of predict
# --> 461     y_pred = self._vectorize("predict", X=X_inner, fh=fh)
#     463 # convert to output mtype, identical with last y mtype seen
#     464 y_out = convert_to(
#     465     y_pred,
#     466     self._y_metadata["mtype"],
#     467     store=self._converter_store_y,
#     468     store_behaviour="freeze",
#     469 )
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\base\_base.py:2061, in BaseForecaster._vectorize(self, methodname, **kwargs)
#    2058 if methodname == "update_predict_single":
#    2059     self._yvec = y
# -> 2061 y_preds = self._yvec.vectorize_est(
#    2062     self.forecasters_,
#    2063     method=methodname,
#    2064     return_type="list",
#    2065     backend=self.get_config()["backend:parallel"],
#    2066     backend_params=self.get_config()["backend:parallel:params"],
#    2067     **kwargs,
#    2068 )
#    2070 # if we vectorize over columns,
#    2071 #   we need to replace top column level with variable names - part 1
#    2072 m = len(self.forecasters_.columns)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\datatypes\_vectorize.py:639, in VectorizedDF.vectorize_est(self, estimator, method, args, args_rowvec, return_type, rowname_default, colname_default, varname_of_self, backend, backend_params, **kwargs)
#     625 vec_zip = zip(
#     626     self.items(),
#     627     explode(args, iterate_as=iterate_as, iterate_cols=iterate_cols),
#     628     explode(args_rowvec, iterate_as=iterate_as, iterate_cols=False),
#     629     estimators,
#     630 )
#     632 meta = {
#     633     "method": method,
#     634     "varname_of_self": varname_of_self,
#     635     "rowname_default": rowname_default,
#     636     "colname_default": colname_default,
#     637 }
# --> 639 ret = parallelize(
#     640     fun=self._vectorize_est_single,
#     641     iter=vec_zip,
#     642     meta=meta,
#     643     backend=backend,
#     644     backend_params=backend_params,
#     645 )
#     647 if return_type == "pd.DataFrame":
#     648     df_long = pd.DataFrame(ret)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\utils\parallel.py:86, in parallelize(fun, iter, meta, backend, backend_params)
#      83 backend_name = backend_dict[backend]
#      84 para_fun = para_dict[backend_name]
# ---> 86 ret = para_fun(
#      87     fun=fun, iter=iter, meta=meta, backend=backend, backend_params=backend_params
#      88 )
#      89 return ret
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\utils\parallel.py:107, in _parallelize_none(fun, iter, meta, backend, backend_params)
#     105 def _parallelize_none(fun, iter, meta, backend, backend_params):
#     106     """Execute loop via simple sequential list comprehension."""
# --> 107     ret = [fun(x, meta=meta) for x in iter]
#     108     return ret
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\datatypes\_vectorize.py:688, in VectorizedDF._vectorize_est_single(self, vec_tuple, meta)
#     685     args_i[varname_of_self] = group
#     687 est_i_method = getattr(est_i, method)
# --> 688 est_i_result = est_i_method(**args_i)
#     690 if group_name is None:
#     691     group_name = rowname_default
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\chronos.py:520, in ChronosForecaster.predict(self, fh, X, y)
#     517 if y is not None:
#     518     return self.fit_predict(fh=_fh, X=X, y=y)
# --> 520 return super().predict(fh=fh, X=X)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\base\_base.py:458, in BaseForecaster.predict(self, fh, X)
#     456 # we call the ordinary _predict if no looping/vectorization needed
#     457 if not self._is_vectorized:
# --> 458     y_pred = self._predict(fh=fh, X=X_inner)
#     459 else:
#     460     # otherwise we call the vectorized version of predict
#     461     y_pred = self._vectorize("predict", X=X_inner, fh=fh)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\chronos.py:559, in ChronosForecaster._predict(self, fh, y, X)
#     556     _y_i = _y[i, :, 0]
#     557     _y_i = _y_i[-self.model_pipeline.model.config.context_length :]
# --> 559     values = self.model_strategy.predict(
#     560         self.model_pipeline, torch.Tensor(_y_i), prediction_length, self._config
#     561     )
#     562     results.append(values)
#     564 pred = np.stack(results, axis=1)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\forecasting\chronos.py:171, in ChronosBoltStrategy.predict(self, pipeline, y_tensor, prediction_length, config)
#     168 def predict(
#     169     self, pipeline, y_tensor: torch.Tensor, prediction_length: int, config: dict
#     170 ) -> np.ndarray:
# --> 171     prediction_results = pipeline.predict(
#     172         y_tensor,
#     173         prediction_length,
#     174         limit_prediction_length=config["limit_prediction_length"],
#     175     )
#     176     return np.median(prediction_results[0].numpy(), axis=0)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\libs\chronos\chronos_bolt.py:721, in ChronosBoltPipeline.predict(self, context, prediction_length, limit_prediction_length)
#     719 while remaining > 0:
#     720     with torch.no_grad():
# --> 721         prediction = self.model(
#     722             context=context_tensor,
#     723         ).quantile_preds.to(context_tensor)
#     725     predictions.append(prediction)
#     726     remaining -= prediction.shape[-1]
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\libs\chronos\chronos_bolt.py:456, in ChronosBoltModelForForecasting.forward(self, context, mask, target, target_mask)
#     451 batch_size = context.size(0)
#     453 hidden_states, loc_scale, input_embeds, attention_mask = self.encode(
#     454     context=context, mask=mask
#     455 )
# --> 456 sequence_output = self.decode(input_embeds, attention_mask, hidden_states)
#     458 quantile_preds_shape = (
#     459     batch_size,
#     460     self.num_quantiles,
#     461     self.chronos_config.prediction_length,
#     462 )
#     463 quantile_preds = self.output_patch_embedding(sequence_output).view(
#     464     *quantile_preds_shape
#     465 )
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\sktime\libs\chronos\chronos_bolt.py:562, in ChronosBoltModelForForecasting.decode(self, input_embeds, attention_mask, hidden_states, output_attentions)
#     556 batch_size = input_embeds.shape[0]
#     557 decoder_input_ids = torch.full(
#     558     (batch_size, 1),
#     559     self.config.decoder_start_token_id,
#     560     device=input_embeds.device,
#     561 )
# --> 562 decoder_outputs = self.decoder(
#     563     input_ids=decoder_input_ids,
#     564     encoder_hidden_states=hidden_states,
#     565     encoder_attention_mask=attention_mask,
#     566     output_attentions=output_attentions,
#     567     return_dict=True,
#     568 )
#     570 return decoder_outputs.last_hidden_state
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\transformers\models\t5\modeling_t5.py:1100, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1097 if output_hidden_states:
#    1098     all_hidden_states = all_hidden_states + (hidden_states,)
# -> 1100 layer_outputs = layer_module(
#    1101     hidden_states,
#    1102     causal_mask,
#    1103     position_bias,
#    1104     encoder_hidden_states,
#    1105     encoder_extended_attention_mask,
#    1106     encoder_decoder_position_bias,  # as a positional argument for gradient checkpointing
#    1107     layer_head_mask=layer_head_mask,
#    1108     cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1109     past_key_values=past_key_values,
#    1110     use_cache=use_cache,
#    1111     output_attentions=output_attentions,
#    1112     return_dict=return_dict,
#    1113     cache_position=cache_position,
#    1114 )
#    1116 hidden_states = layer_outputs[0]
#    1118 # We share the position biases between the layers - the first layer store them
#    1119 # layer_outputs = hidden-states, key-value-states (self-attention position bias), (self-attention weights),
#    1120 # (cross-attention position bias), (cross-attention weights)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\transformers\models\t5\modeling_t5.py:711, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_values, use_cache, output_attentions, return_dict, cache_position)
#     709 do_cross_attention = self.is_decoder and encoder_hidden_states is not None
#     710 if do_cross_attention:
# --> 711     cross_attention_outputs = self.layer[1](
#     712         hidden_states,
#     713         key_value_states=encoder_hidden_states,
#     714         attention_mask=encoder_attention_mask,
#     715         position_bias=encoder_decoder_position_bias,
#     716         layer_head_mask=cross_attn_layer_head_mask,
#     717         past_key_values=past_key_values,
#     718         query_length=cache_position[-1] + 1,
#     719         use_cache=use_cache,
#     720         output_attentions=output_attentions,
#     721     )
#     722     hidden_states = cross_attention_outputs[0]
#     724     # clamp inf values to enable fp16 training
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\transformers\models\t5\modeling_t5.py:640, in T5LayerCrossAttention.forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_values, use_cache, query_length, output_attentions, cache_position)
#     625 @deprecate_kwarg("past_key_value", new_name="past_key_values", version="4.58")
#     626 def forward(
#     627     self,
#    (...)    637     cache_position=None,
#     638 ):
#     639     normed_hidden_states = self.layer_norm(hidden_states)
# --> 640     attention_output = self.EncDecAttention(
#     641         normed_hidden_states,
#     642         mask=attention_mask,
#     643         key_value_states=key_value_states,
#     644         position_bias=position_bias,
#     645         layer_head_mask=layer_head_mask,
#     646         past_key_values=past_key_values,
#     647         use_cache=use_cache,
#     648         query_length=query_length,
#     649         output_attentions=output_attentions,
#     650         cache_position=cache_position,
#     651     )
#     652     layer_output = hidden_states + self.dropout(attention_output[0])
#     653     outputs = (layer_output,) + attention_output[1:]  # add attentions if we output them
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\Trajan\Documents\projects\tutorial_haicon_prologue_day\.venv\Lib\site-packages\transformers\models\t5\modeling_t5.py:549, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_values, layer_head_mask, query_length, use_cache, output_attentions, cache_position)
#     547     if mask is not None:
#     548         causal_mask = mask[:, :, :, : key_states.shape[-2]]
# --> 549         position_bias = position_bias + causal_mask
#     551 if self.pruned_heads:
#     552     mask = torch.ones(position_bias.shape[1])
#
# RuntimeError: The size of tensor a (71) must match the size of tensor b (70) at non-singleton dimension 3

# %%
results.columns

# %%
results.set_index("model_id")["MeanSquaredError_mean"].plot.bar(title="Mean Squared Error", figsize=(12, 6))

# %%
results.set_index("model_id")[["pred_time_mean", "fit_time_mean", "runtime_secs"]].plot.bar(title="Run Times", figsize=(12, 6), logy=True)

# %%
import matplotlib.pyplot as plt
legends = []
for model, row in results[["model_id", "MeanAbsoluteError_mean"]].set_index("model_id").iterrows():
    legends.append(model)
    row["MeanAbsoluteError_mean"].plot(figsize=(12, 6))
plt.legend(legends)
plt.show()
